# %%
#Dependencies 
# %matplotlib inline 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime

# %%
data_file = "US_Accidents_May19 2018_2019.csv"

# %%
data_file_df = pd.read_csv(data_file)
data_file_df.head()
# Out:
#          ID  Severity      Start_Time        End_Time  Start_Lat  Start_Lng  \
# 0  A-512230         3   3/3/2019 9:53  3/3/2019 10:22  42.338089 -79.586700
# 1  A-512231         3  3/3/2019 15:25  3/3/2019 15:55  42.743877 -78.845070
# 2  A-512232         3  3/3/2019 17:36  3/3/2019 18:06  43.004314 -78.946648
# 3  A-512233         3  3/3/2019 17:48  3/3/2019 18:18  43.074436 -78.990921
# 4  A-512234         2  3/3/2019 17:54  3/3/2019 18:24  41.946899 -78.672333
#
#    Distance(mi)                                        Description  Number  \
# 0           0.0  Accident on I-90 Westbound after Exit 60 NY-39...     NaN
# 1           0.0  Accident on I-90 Westbound at Exit 57 NY-75 Ca...     NaN
# 2           0.0  Accident on I-190 Northbound at Exits 18 18A 1...     NaN
# 3           0.0  Accident on I-190 Southbound at Exits 21 21A N...     NaN
# 4           0.0  Delays due to accident on PA-346 Washington St...   451.0
#
# ...

# %%
new_data_df = data_file_df[["ID","Start_Time","End_Time", "Start_Lat", "Start_Lng", "City", "State", "Temperature(F)", "Weather_Condition","Astronomical_Twilight"]]
new_data_df.head()
# Out:
#          ID      Start_Time        End_Time  Start_Lat  Start_Lng  \
# 0  A-512230   3/3/2019 9:53  3/3/2019 10:22  42.338089 -79.586700
# 1  A-512231  3/3/2019 15:25  3/3/2019 15:55  42.743877 -78.845070
# 2  A-512232  3/3/2019 17:36  3/3/2019 18:06  43.004314 -78.946648
# 3  A-512233  3/3/2019 17:48  3/3/2019 18:18  43.074436 -78.990921
# 4  A-512234  3/3/2019 17:54  3/3/2019 18:24  41.946899 -78.672333
#
#             City State  Temperature(F) Weather_Condition Astronomical_Twilight
# 0      Westfield    NY            26.1     Mostly Cloudy                   Day
# 1        Hamburg    NY            28.0          Overcast                   Day
# 2   Grand Island    NY            25.0        Light Snow                   Day
# 3  Niagara Falls    NY            25.0        Light Snow                   Day
# 4       Bradford    PA            24.1              Snow                   Day

# %%
new_data_df["Year"] = pd.DatetimeIndex(new_data_df["Start_Time"]).year
new_data_df.head()
# Out:
# C:\Users\nidas\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#          ID      Start_Time        End_Time  Start_Lat  Start_Lng  \
# 0  A-512230   3/3/2019 9:53  3/3/2019 10:22  42.338089 -79.586700
# 1  A-512231  3/3/2019 15:25  3/3/2019 15:55  42.743877 -78.845070
# 2  A-512232  3/3/2019 17:36  3/3/2019 18:06  43.004314 -78.946648
# 3  A-512233  3/3/2019 17:48  3/3/2019 18:18  43.074436 -78.990921
# 4  A-512234  3/3/2019 17:54  3/3/2019 18:24  41.946899 -78.672333
#
#             City State  Temperature(F) Weather_Condition  \
# 0      Westfield    NY            26.1     Mostly Cloudy
# 1        Hamburg    NY            28.0          Overcast
# ...

# %%
data = new_data_df.loc[new_data_df["Year"]>2017]

# %%
# data.index.name='ID'
# data = data.reset_index(drop=True)
# final_data = data.drop(data.index[172867:536348])
# final_data

# %%
data.to_csv(r'FinalData.csv')
